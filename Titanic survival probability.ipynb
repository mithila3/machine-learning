# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import math
# %matplotlib inline

titanic_data = pd.read_csv("C:\Python\Titanic.csv")
titanic_data.head()
print(titanic_data.shape)
print(titanic_data.head(10))
# Out:
# (1309, 14)
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# ## Analyze Data

# %%
sns.countplot(x="survived", data=titanic_data)

# %%
sns.countplot(x="survived", hue="sex", data=titanic_data)

# %%
sns.countplot(x="survived", hue="pclass", data=titanic_data)

# %%
titanic_data["age"].plot.hist()

# %%
titanic_data["fare"].plot.hist(bins=20, figsize=(10,5))

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1058 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         490 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %%
titanic_data["pclass"].plot.hist(bins=20, figsize=(5,5))

# %%
sns.countplot("sibsp", data=titanic_data)

# %%
sns.countplot("parch", data=titanic_data)

# %% [markdown]
# ## Data Wrangling

# %%
titanic_data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           251
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          819
# body         1188
# home.dest     564
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull(), yticklabels=False, cmap="YlGnBu")

# %%
sns.boxplot(x="pclass", y="age", data=titanic_data, )

# %%
titanic_data.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic_data.drop("body",axis=1,inplace=True )

# %%
titanic_data.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_data.dropna(inplace=True)

# %%
titanic_data.isnull().sum()
titanic_data.head(2)
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 0 to 605
# Data columns (total 13 columns):
# pclass       161 non-null int64
# survived     161 non-null int64
# name         161 non-null object
# sex          161 non-null object
# age          161 non-null float64
# sibsp        161 non-null int64
# parch        161 non-null int64
# ticket       161 non-null object
# fare         161 non-null float64
# cabin        161 non-null object
# embarked     161 non-null object
# boat         161 non-null object
# home.dest    161 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 17.6+ KB

# %%
sns.heatmap(titanic_data.isnull(),yticklabels=False )

# %%
titanic_data.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# home.dest    0
# dtype: int64

# %%
sex=pd.get_dummies(titanic_data["sex"],drop_first = True)
sex.head(5)
# Out:
#    male
# 0     0
# 1     1
# 5     1
# 6     0
# 8     0

# %%
titanic_data.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch  ticket      fare    cabin embarked boat  \
# 0      0   24160  211.3375       B5        S    2
# 1      2  113781  151.5500  C22 C26        S   11
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
embark=pd.get_dummies(titanic_data["embarked"], drop_first=True)

# %%
embark.head(5)
# Out:
#    Q  S
# 0  0  1
# 1  0  1
# 5  0  1
# 6  0  1
# 8  0  1

# %%
pclass = pd.get_dummies(titanic_data["pclass"], drop_first=True)
pclass.head(5)
# Out:
#    2  3
# 0  0  0
# 1  0  0
# 5  0  0
# 6  0  0
# 8  0  0

# %%
titanic_data=pd.concat([titanic_data,sex,embark,pclass],axis=1)

# %%
titanic_data.shape
titanic_data.tail(1300)
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
# 16        1         0                           Baxter, Mr. Quigg Edmond
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 19        1         0                               Beattie, Mr. Thomson
# ...

# %%
titanic_data.drop(["pclass", "sex", "ticket", "embarked","name", "home.dest", "cabin", "boat"],axis=1, inplace=True)

# %%
titanic_data.head(1300)
# Out:
#      survived      age  sibsp  parch      fare  male  Q  S  2  3
# 0           1  29.0000      0      0  211.3375     0  0  1  0  0
# 1           1   0.9167      1      2  151.5500     1  0  1  0  0
# 5           1  48.0000      0      0   26.5500     1  0  1  0  0
# 6           1  63.0000      1      0   77.9583     0  0  1  0  0
# 8           1  53.0000      2      0   51.4792     0  0  1  0  0
# 10          0  47.0000      1      0  227.5250     1  0  0  0  0
# 11          1  18.0000      1      0  227.5250     0  0  0  0  0
# 12          1  24.0000      0      0   69.3000     0  0  0  0  0
# 14          1  80.0000      0      0   30.0000     1  0  1  0  0
# 16          0  24.0000      0      1  247.5208     1  0  0  0  0
# 17          1  50.0000      0      1  247.5208     0  0  0  0  0
# 19          0  36.0000      0      0   75.2417     1  0  0  0  0
# 20          1  37.0000      1      1   52.5542     1  0  1  0  0
# ...

# %%
#aa=titanic_data["survived"]
#print(aa)
#titanic_data.head()

# %%
titanic_data.head(5)
print(titanic_data.shape)
# Out:
# (161, 10)

# %% [markdown]
# ### Training and test

# %%
# Features or independent variables
#x=titanic_data.drop("survived",axis=1)

# Dependent variable
#y=titanic_data["survived"]

# splitting 30% as test data
#from sklearn.cross_validation import train_test_split
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test = train_test_split (x,y,test_size=0.3, random_state=1)


X=titanic_data.drop("survived", axis=1)
Y=titanic_data["survived"]
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3, random_state=1)

# %% [markdown]
# ## Training

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
classification_report(Y_test,predictions)
# Out:
# C:\Users\mithila.shashidhar\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# '             precision    recall  f1-score   support\n\n          0       0.00      0.00      0.00         2\n          1       0.96      1.00      0.98        47\n\navg / total       0.92      0.96      0.94        49\n'

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predictions)
# Out:
# array([[ 0,  2],
#        [ 0, 47]], dtype=int64)
